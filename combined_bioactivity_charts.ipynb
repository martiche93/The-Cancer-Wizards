# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read in CSVs
bioactivity_data_one = pd.read_csv("Resources/tryptase_data/tryptase_bioactivity_preprocessed_data.csv")
bioactivity_data_two = pd.read_csv("Resources/pdl1_data/pdl1_bioactivity_preprocessed_data.csv")

# %%
# Check to see how many rows dataframe 1 has - 167 rows
bioactivity_data_one
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL432835  CC(C)C(OC(=O)N1CCN(C(=O)N2C(=O)[C@H](CC3CCN(C(...
# 1         CHEMBL324621  CC(C)C(OC(=O)N1CCN(C(=O)N2C(=O)[C@H](CC3CCCN(C...
# 2         CHEMBL324621  CC(C)C(OC(=O)N1CCN(C(=O)N2C(=O)[C@H](CC3CCCN(C...
# 3         CHEMBL109504  N=C(N)N1CCCC(C[C@H]2C(=O)N(C(=O)N3CCN(C(=O)CCC...
# 4         CHEMBL324621  CC(C)C(OC(=O)N1CCN(C(=O)N2C(=O)[C@H](CC3CCCN(C...
# ..                 ...                                                ...
# 162       CHEMBL107226  NCCCCCCNC(=O)CN1CCCCC(NC(=O)c2ccc(-c3ccccc3)cc...
# 163       CHEMBL326694  NCCc1ccc(NC(=O)CN2CCCCC(NC(=O)c3ccc(-c4ccccc4)...
# 164       CHEMBL320473  NCc1cccc(NC(=O)CN2CCCCC(NC(=O)c3ccc(Cc4ccccc4)...
# 165      CHEMBL3604626       CN1C(=O)c2ccc(OC(=O)CCc3ccc(N)nc3)cc2C1=O.Cl
# 166        CHEMBL71037  CC(C)(C)NC(=O)N1CCN(C(=O)N2C(=O)[C@H](CCCN=C(N...
#
#     bioactivity_class  standard_value
# 0              active             9.0
# ...

# %%
# Check to see how many rows dataframe 2 has - 25 rows
bioactivity_data_two
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL3582257  COc1cc(OCc2cccc(-c3ccccc3)c2C)cc(OC)c1CNC(CO)(...
# 1       CHEMBL3582256  COc1cc(OCc2cccc(-c3ccccc3)c2C#N)cc(OC)c1CN1CCC...
# 2       CHEMBL3582255     Cc1c(COc2ccc(CNCC3CCC(=O)N3)cc2)cccc1-c1ccccc1
# 3       CHEMBL3582254  Cc1c(COc2ccc(CN[C@H](C)C(=O)O)cc2Cl)cccc1-c1cc...
# 4       CHEMBL3582253  Cc1cc(CN2CCC(C(=O)NCCO)CC2)ccc1OCc1cccc(-c2ccc...
# 5       CHEMBL3582252  COc1cc(OCc2cccc(-c3ccccc3)c2C)cc(OC)c1CN1CCCC[...
# 6       CHEMBL4081869  COc1cc(OCc2cccc(-c3ccccc3)c2C)cc(OC)c1CNCCNC(C)=O
# 7       CHEMBL4099869  Cc1c(COc2ccc(CN3CCCCC3C(=O)O)cc2Br)cccc1-c1ccccc1
# 8       CHEMBL4089730      COc1nc(OCc2cccc(-c3ccccc3)c2C)ccc1CNCCNC(C)=O
# 9       CHEMBL4061613  COc1cc(OCc2cccc(-c3ccccc3)c2C)cc(OC)c1CN[C@@H]...
# 10      CHEMBL4062686  Cc1c(COc2cc(F)c(CNC[C@@H](O)CC(=O)O)cc2F)cccc1...
# 11      CHEMBL4084368  Cc1cc(CN[C@H](CO)C(=O)O)c(OCc2cccc(C#N)c2)cc1O...
# ...

# %%
combined_bioactivity_data = [bioactivity_data_one, bioactivity_data_two]

# %%
# Concat the 2 dataframes
df = pd.concat(combined_bioactivity_data)

# %%
# Check to see if 167 and 25 rows adds up to 192 and it does!
df
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL432835  CC(C)C(OC(=O)N1CCN(C(=O)N2C(=O)[C@H](CC3CCN(C(...
# 1        CHEMBL324621  CC(C)C(OC(=O)N1CCN(C(=O)N2C(=O)[C@H](CC3CCCN(C...
# 2        CHEMBL324621  CC(C)C(OC(=O)N1CCN(C(=O)N2C(=O)[C@H](CC3CCCN(C...
# 3        CHEMBL109504  N=C(N)N1CCCC(C[C@H]2C(=O)N(C(=O)N3CCN(C(=O)CCC...
# 4        CHEMBL324621  CC(C)C(OC(=O)N1CCN(C(=O)N2C(=O)[C@H](CC3CCCN(C...
# ..                ...                                                ...
# 20      CHEMBL4637826          Cc1c(-c2ccccc2)cccc1-c1nc2cc(CNCCO)ccc2o1
# 21      CHEMBL4633569  N#Cc1cncc(COc2cc(O[C@H]3CCc4c(-c5ccccc5)cccc43...
# 22       CHEMBL366760  O=C(/C=C/c1ccc(O)c(O)c1)O[C@H]1C[C@@](O)(C(=O)...
# 23      CHEMBL4081869  COc1cc(OCc2cccc(-c3ccccc3)c2C)cc(OC)c1CNCCNC(C)=O
# 24      CHEMBL4062686  Cc1c(COc2cc(F)c(CNC[C@@H](O)CC(=O)O)cc2F)cccc1...
#
#    bioactivity_class  standard_value
# 0             active             9.0
# ...

# %%
df.to_csv('Resources/combined_bioactivity_data.csv', index=False)
