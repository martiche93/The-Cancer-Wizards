# %%
# import dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
# read in csv & create df
df = pd.read_csv("../Resources/label_encoded_breast_cancer_prediction.csv")
df
# Out:
#      Unnamed: 0        id  diagnosis  radius_mean  texture_mean  \
# 0             0    842302          1        17.99         10.38
# 1             1    842517          1        20.57         17.77
# 2             2  84300903          1        19.69         21.25
# 3             3  84348301          1        11.42         20.38
# 4             4  84358402          1        20.29         14.34
# ..          ...       ...        ...          ...           ...
# 564         564    926424          1        21.56         22.39
# 565         565    926682          1        20.13         28.25
# 566         566    926954          1        16.60         28.08
# 567         567    927241          1        20.60         29.33
# 568         568     92751          0         7.76         24.54
#
#      perimeter_mean  area_mean  smoothness_mean  compactness_mean  \
# 0            122.80     1001.0          0.11840           0.27760
# ...

# %%
df.drop(["Unnamed: 0"], axis=1)
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
# assign X(data) & y(target)
# y = diagnosis, must be dropped from the X df
X = df.drop("diagnosis", axis = 1)
y = df["diagnosis"]
print(X.shape, y.shape)
# Out:
# (569, 32) (569,)

# %%
# Split the data using train_test_split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
# scale the data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Create a Decision Tree Classifier
from sklearn import tree

dt = tree.DecisionTreeClassifier()
dt.fit(X_train, y_train)
dt.score(X_test, y_test)
# Out:
# 0.951048951048951

# %%
# Fit the classifier to the data
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators = 500)
rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.972027972027972

# %%
#make use of trained model to make predictions on test data
y_predictions = rf.predict(X_test)
type(y_predictions)
# Out:
# numpy.ndarray

# %%
#plot confusion matrix
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

data = confusion_matrix(y_test, y_predictions)
df_cm = pd.DataFrame(data, columns = np.unique(y_test), index = np.unique(y_test))
df_cm.index.name = "Actual"
df_cm.columns.name = "Predicted"
plt.figure(figsize = (10, 7))
sns.set(font_scale = 1.4)
confusion_matrix_plot = sns.heatmap(df_cm, cmap = "Blues", annot = True, annot_kws = {"size": 16})
confusion_matrix_plot.figure.savefig("RANDOM_FOREST_MODEL_confusion_matrix_plot.png")

# %% [markdown]
# ## **REMEMBER: Benign = 0 & Malignant = 1**
# **The above confusion matrix visually shows how our model did:**
#
# 88 True Positives = True Benign Tumors
#
# 1 False Positives = Predicted to be Malignant Tumors, but actually Benign Tumors
#
# 3 False Negatives = Predicted to be Benign Tumors, but actually Malignant Tumors
#
# 51 True Negatives = True Malignant Tumors

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test, y_predictions)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        89
#            1       0.98      0.94      0.96        54
#
#     accuracy                           0.97       143
#    macro avg       0.97      0.97      0.97       143
# weighted avg       0.97      0.97      0.97       143

# %%
#create dataframe to compare our model's prediction performance
prediction_df = pd.DataFrame(
    {
        "Predictive Diagnosis": y_predictions, 
        "Actual Diagnosis": y_test
    })
prediction_df
# Out:
#      Predictive Diagnosis  Actual Diagnosis
# 204                     0                 0
# 70                      1                 1
# 131                     1                 1
# 431                     0                 0
# 540                     0                 0
# ..                    ...               ...
# 89                      0                 0
# 199                     1                 1
# 411                     0                 0
# 18                      1                 1
# 390                     0                 0
#
# [143 rows x 2 columns]

# %%
#save predicted df to CSV file
prediction_df.to_csv("../Prediction_Output_CSVs/Random_Forest_Model_Prediction.csv")
