# %% [markdown]
# ## **Installing libraries**

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.7/dist-packages (0.10.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (2.23.0)
# Requirement already satisfied: easydict in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: requests-cache~=0.7.0 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (0.7.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.0.1)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (5.4.1)
# Requirement already satisfied: attrs<22.0,>=21.2 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.2.0)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Target search for Tryptase**

# %%
# Target search for Tryptase protein
target = new_client.target
target_query = target.search('tryptase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  ... tax_id
# 0                                                  []  ...   9606
# 1   [{'xref_id': 'Q15661', 'xref_name': None, 'xre...  ...   9606
# 2   [{'xref_id': 'TPSG1', 'xref_name': None, 'xref...  ...   9606
# 3                                                  []  ...   9606
# 4   [{'xref_id': 'P27435', 'xref_name': None, 'xre...  ...  10116
# 5   [{'xref_id': 'P15944', 'xref_name': None, 'xre...  ...   9615
# 6   [{'xref_id': 'Q02844', 'xref_name': None, 'xre...  ...  10090
# 7                                                  []  ...  10090
# 8   [{'xref_id': 'P49864', 'xref_name': None, 'xre...  ...  10116
# 9   [{'xref_id': 'P49863', 'xref_name': None, 'xre...  ...   9606
# 10  [{'xref_id': 'GZMA', 'xref_name': None, 'xref_...  ...   9606
#
# [11 rows x 9 columns]

# %% [markdown]
# ## **Select and retrieve bioactivity data for Tryptase (first entry)**

# %% [markdown]
# We will assign the first entry (which corresponds to the target protein, Tryptase in Homo sapiens) to the selected_target variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL2095193'

# %% [markdown]
# Here, we will retrieve only bioactivity data for Tryptase (CHEMBL2095193) that are reported as $IC_{50}$ values in nM (nanomolar) unit. $IC_{50}$ is used for the measure of antagonist drug potency in pharmacological research.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   activity_comment  activity_id  ... upper_value  value
# 0             None       266666  ...        None    9.0
# 1             None       269175  ...        None   71.0
# 2             None       270490  ...        None  204.0
#
# [3 rows x 45 columns]

# %% [markdown]
# We want a 'standard_value' to be as low as possible to see which compounds or pharmacological drugs interact the most with Tryptase, which is the main biomarker for mast cells. High Tryptase levels indicate either allergic reactions or mastocytosis (mast cell cancer).

# %% [markdown]
# Using the 'unique' function, we can see that only $IC_{50}$ is present in the DataFrame

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally, we will save the resulting bioactivity data to a CSV file **tryptase_bioactivity_data.csv**.

# %%
df.to_csv('tryptase_bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/tryptase_data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/tryptase_data’: File exists

# %%
! cp tryptase_bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/tryptase_data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/tryptase_data"
# Out:
# total 150
# -rw------- 1 root root 77656 Aug 22 09:28 tryptase_bioactivity_data.csv
# -rw------- 1 root root 15509 Aug 22 09:26 tryptase_bioactivity_preprocessed_data.csv
# -rw------- 1 root root 59136 Aug 22 09:26 Tryptase_data.ipynb

# %%
! head tryptase_bioactivity_data.csv
# Out:
# activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,266666,[],CHEMBL817298,Inhibitory concentration against human tryptase,B,,,BAO_0000190,BAO_0000224,protein format,CC(C)C(OC(=O)N1CCN(C(=O)N2C(=O)[C@H](CC3CCN(C(=N)N)C3)[C@H]2C(=O)O)CC1)C(C)C,,,CHEMBL1134958,Bioorg. Med. Chem. Lett.,2002,"{'bei': '16.27', 'le': '0.31', 'lle': '6.99', 'sei': '5.01'}",CHEMBL432835,,CHEMBL432835,8.05,False,http://www.openphacts.org/units/Nanomolar,207080,=,1,True,=,,IC50,nM,,9.0,CHEMBL2095193,Homo sapiens,Tryptase,9606,,,IC50,nM,UO_0000065,,9.0
# ,269175,[],CHEMBL817298,Inhibitory concentration against human tryptase,B,,,BAO_0000190,BAO_0000224,protein format,CC(C)C(OC(=O)N1CCN(C(=O)N2C(=O)[C@H](CC3CCCN(C(=N)N)C3)[C@H]2C(=O)O)CC1)C(C)C,,,CHEMBL1134958,Bioorg. Med. Chem. Lett.,2002,"{'bei': '14.06', 'le': '0.27', 'lle': '5.70', 'sei': '4.45'}",CHEMBL324621,,CHEMBL324621,7.15,False,http://www.openphacts.org/units/Nanomolar,207082,=,1,True,=,,IC50,nM,,71.0,CHEMBL2095193,Homo sapiens,Tryptase,9606,,,IC50,nM,UO_0000065,,71.0
# ,270490,[],CHEMBL817298,Inhibitory concentration against human tryptase,B,,,BAO_0000190,BAO_0000224,protein format,CC(C)C(OC(=O)N1CCN(C(=O)N2C(=O)[C@H](CC3CCCN(C(=N)N)C3)[C@H]2C(=O)O)CC1)C(C)C,,,CHEMBL1134958,Bioorg. Med. Chem. Lett.,2002,"{'bei': '13.15', 'le': '0.25', 'lle': '5.24', 'sei': '4.17'}",CHEMBL324621,,CHEMBL324621,6.69,False,http://www.openphacts.org/units/Nanomolar,207083,=,1,True,=,,IC50,nM,,204.0,CHEMBL2095193,Homo sapiens,Tryptase,9606,,,IC50,nM,UO_0000065,,204.0
# ,271838,[],CHEMBL817298,Inhibitory concentration against human tryptase,B,,,BAO_0000190,BAO_0000224,protein format,N=C(N)N1CCCC(C[C@H]2C(=O)N(C(=O)N3CCN(C(=O)CCCCCC4CCCCC4)CC3)[C@@H]2C(=O)O)C1,,,CHEMBL1134958,Bioorg. Med. Chem. Lett.,2002,"{'bei': '15.95', 'le': '0.31', 'lle': '6.03', 'sei': '5.76'}",CHEMBL109504,,CHEMBL109504,8.72,False,http://www.openphacts.org/units/Nanomolar,207085,=,1,True,=,,IC50,nM,,1.9,CHEMBL2095193,Homo sapiens,Tryptase,9606,,,IC50,nM,UO_0000065,,1.9
# ,275325,[],CHEMBL817298,Inhibitory concentration against human tryptase,B,,,BAO_0000190,BAO_0000224,protein format,CC(C)C(OC(=O)N1CCN(C(=O)N2C(=O)[C@H](CC3CCCN(C(=N)N)C3)[C@H]2C(=O)O)CC1)C(C)C,,,CHEMBL1134958,Bioorg. Med. Chem. Lett.,2002,"{'bei': '14.16', 'le': '0.27', 'lle': '5.75', 'sei': '4.48'}",CHEMBL324621,,CHEMBL324621,7.20,False,http://www.openphacts.org/units/Nanomolar,207094,=,1,True,=,,IC50,nM,,63.0,CHEMBL2095193,Homo sapiens,Tryptase,9606,,,IC50,nM,UO_0000065,,63.0
# ,275331,[],CHEMBL817298,Inhibitory concentration against human tryptase,B,,,BAO_0000190,BAO_0000224,protein format,N=C(N)N1CCC[C@H](C[C@H]2C(=O)N(C(=O)N3CCN(C(=O)CCCCCc4ccccc4)CC3)[C@@H]2C(=O)O)C1,,,CHEMBL1134958,Bioorg. Med. Chem. Lett.,2002,,CHEMBL303437,,CHEMBL303437,,True,http://www.openphacts.org/units/Nanomolar,207089,<,1,True,<,,IC50,nM,,1.7,CHEMBL2095193,Homo sapiens,Tryptase,9606,,,IC50,nM,UO_0000065,,1.7
# ,275339,[],CHEMBL817298,Inhibitory concentration against human tryptase,B,,,BAO_0000190,BAO_0000224,protein format,N=C(N)NCCC[C@H]1C(=O)N(C(=O)N2CCN(C(=O)CCCCCc3ccccc3)CC2)[C@@H]1C(=O)O,,,CHEMBL1134958,Bioorg. Med. Chem. Lett.,2002,,CHEMBL326209,,CHEMBL326209,,False,http://www.openphacts.org/units/Nanomolar,207087,<,1,True,<,,IC50,nM,,1.7,CHEMBL2095193,Homo sapiens,Tryptase,9606,,,IC50,nM,UO_0000065,,1.7
# ,281518,[],CHEMBL817298,Inhibitory concentration against human tryptase,B,,,BAO_0000190,BAO_0000224,protein format,CN(CCCCc1ccccc1)C(=O)N1CCN(C(=O)N2C(=O)[C@H](CC3CCCN(C(=N)N)C3)[C@H]2C(=O)O)CC1,,,CHEMBL1134958,Bioorg. Med. Chem. Lett.,2002,"{'bei': '14.80', 'le': '0.28', 'lle': '6.51', 'sei': '5.32'}",CHEMBL113591,,CHEMBL113591,8.22,False,http://www.openphacts.org/units/Nanomolar,207092,=,1,True,=,,IC50,nM,,6.0,CHEMBL2095193,Homo sapiens,Tryptase,9606,,,IC50,nM,UO_0000065,,6.0
# ,282715,[],CHEMBL817298,Inhibitory concentration against human tryptase,B,,,BAO_0000190,BAO_0000224,protein format,N=C(N)N1CCCC(C[C@H]2C(=O)N(C(=O)N3CCN(C(=O)OCCCOc4ccccc4)CC3)[C@@H]2C(=O)O)C1,,,CHEMBL1134958,Bioorg. Med. Chem. Lett.,2002,,CHEMBL111630,,CHEMBL111630,,False,http://www.openphacts.org/units/Nanomolar,207086,<,1,True,<,,IC50,nM,,1.7,CHEMBL2095193,Homo sapiens,Tryptase,9606,,,IC50,nM,UO_0000065,,1.7

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#     activity_comment  activity_id  ... upper_value    value
# 0               None       266666  ...        None      9.0
# 1               None       269175  ...        None     71.0
# 2               None       270490  ...        None    204.0
# 3               None       271838  ...        None      1.9
# 4               None       275325  ...        None     63.0
# ..               ...          ...  ...         ...      ...
# 162             None      1217854  ...        None  33000.0
# 163             None      1220510  ...        None  11000.0
# 164             None      1222962  ...        None    980.0
# 165             None     15679184  ...        None     0.19
# 166             None     18550707  ...        None      5.0
#
# [167 rows x 45 columns]

# %% [markdown]
# # **Data pre-processing of bioactivity data**

# %% [markdown]
# ### **Labeling compounds aas either being active, inactive, or intermediate**

# %% [markdown]
# The bioactivity data is in the $IC_{50}$ unit. Compounds having values of less than 1,000 nM will be considered to be **active** while those greater than 10,000 nM will be considered **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list because we don't want duplicates**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list because we still don't want duplicates**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate the *standard_value* to a list because again, we don't want duplicates**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into 1 dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#     molecule_chembl_id  ... standard_value
# 0         CHEMBL432835  ...            9.0
# 1         CHEMBL324621  ...           71.0
# 2         CHEMBL324621  ...          204.0
# 3         CHEMBL109504  ...            1.9
# 4         CHEMBL324621  ...           63.0
# ..                 ...  ...            ...
# 162       CHEMBL107226  ...        33000.0
# 163       CHEMBL326694  ...        11000.0
# 164       CHEMBL320473  ...          980.0
# 165      CHEMBL3604626  ...          190.0
# 166        CHEMBL71037  ...            5.0
#
# [167 rows x 4 columns]

# %% [markdown]
# Save the new dataframe to a pre-processed CSV file

# %%
df3.to_csv('tryptase_bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 100
# drwx------ 5 root root  4096 Aug 22 09:28 gdrive
# drwxr-xr-x 1 root root  4096 Aug 13 13:35 sample_data
# -rw-r--r-- 1 root root 77656 Aug 22 09:28 tryptase_bioactivity_data.csv
# -rw-r--r-- 1 root root 15509 Aug 22 09:28 tryptase_bioactivity_preprocessed_data.csv

# %%
! cp tryptase_bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/tryptase_data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/tryptase_data"
# Out:
# tryptase_bioactivity_data.csv		    Tryptase_data.ipynb
# tryptase_bioactivity_preprocessed_data.csv
