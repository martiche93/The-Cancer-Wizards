# %% [markdown]
# # **Computational Drug Discovery [Part 1]**

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#      |████████████████████████████████| 55 kB 1.2 MB/s
# ...
#      |████████████████████████████████| 636 kB 10.7 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.0.1 which is incompatible.
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %%
# Target search for tryptase
target = new_client.target
target_query = target.search('tryptase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  ... tax_id
# 0                                                  []  ...   9606
# 1   [{'xref_id': 'Q15661', 'xref_name': None, 'xre...  ...   9606
# 2   [{'xref_id': 'TPSG1', 'xref_name': None, 'xref...  ...   9606
# 3                                                  []  ...   9606
# 4   [{'xref_id': 'P27435', 'xref_name': None, 'xre...  ...  10116
# 5   [{'xref_id': 'P15944', 'xref_name': None, 'xre...  ...   9615
# 6   [{'xref_id': 'Q02844', 'xref_name': None, 'xre...  ...  10090
# 7                                                  []  ...  10090
# 8   [{'xref_id': 'P49864', 'xref_name': None, 'xre...  ...  10116
# 9   [{'xref_id': 'P49863', 'xref_name': None, 'xre...  ...   9606
# 10  [{'xref_id': 'GZMA', 'xref_name': None, 'xref_...  ...   9606
#
# [11 rows x 9 columns]

# %% [markdown]
# We will assign the first entry (which corresponds to the target protein, *trytase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL2095193'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *tryptase* (CHEMBL2095193) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#     activity_comment  activity_id  ... upper_value    value
# 0               None       266666  ...        None      9.0
# 1               None       269175  ...        None     71.0
# 2               None       270490  ...        None    204.0
# 3               None       271838  ...        None      1.9
# 4               None       275325  ...        None     63.0
# ..               ...          ...  ...         ...      ...
# 162             None      1217854  ...        None  33000.0
# 163             None      1220510  ...        None  11000.0
# 164             None      1222962  ...        None    980.0
# 165             None     15679184  ...        None     0.19
# 166             None     18550707  ...        None      5.0
#
# [167 rows x 45 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **TRYPTASE_TEST_bioactivity_data.csv**.

# %%
df.to_csv('TRYPTASE_TEST_bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/TRYPTASE_TEST"

# %%
! cp TRYPTASE_TEST_bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/TRYPTASE_TEST"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/TRYPTASE_TEST"
# Out:
# total 76
# -rw------- 1 root root 77656 Aug 26 19:10 TRYPTASE_TEST_bioactivity_data.csv

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# gdrive	sample_data  TRYPTASE_TEST_bioactivity_data.csv

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! head TRYPTASE_TEST_bioactivity_data.csv
# Out:
# activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#     activity_comment  activity_id  ... upper_value    value
# 0               None       266666  ...        None      9.0
# 1               None       269175  ...        None     71.0
# 2               None       270490  ...        None    204.0
# 3               None       271838  ...        None      1.9
# 4               None       275325  ...        None     63.0
# ..               ...          ...  ...         ...      ...
# 162             None      1217854  ...        None  33000.0
# 163             None      1220510  ...        None  11000.0
# 164             None      1222962  ...        None    980.0
# 165             None     15679184  ...        None     0.19
# 166             None     18550707  ...        None      5.0
#
# [167 rows x 45 columns]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#     molecule_chembl_id  ... standard_value
# 0         CHEMBL432835  ...            9.0
# 1         CHEMBL324621  ...           71.0
# 2         CHEMBL324621  ...          204.0
# 3         CHEMBL109504  ...            1.9
# 4         CHEMBL324621  ...           63.0
# ..                 ...  ...            ...
# 162       CHEMBL107226  ...        33000.0
# 163       CHEMBL326694  ...        11000.0
# 164       CHEMBL320473  ...          980.0
# 165      CHEMBL3604626  ...          190.0
# 166        CHEMBL71037  ...            5.0
#
# [167 rows x 4 columns]

# %% [markdown]
# ### **Alternative method**

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('TRYPTASE_TEST_bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 100
# drwx------ 5 root root  4096 Aug 26 18:49 gdrive
# drwxr-xr-x 1 root root  4096 Aug 25 13:35 sample_data
# -rw-r--r-- 1 root root 77656 Aug 26 18:48 TRYPTASE_TEST_bioactivity_data.csv
# -rw-r--r-- 1 root root 15509 Aug 26 19:11 TRYPTASE_TEST_bioactivity_preprocessed_data.csv

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp TRYPTASE_TEST_bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/TRYPTASE_TEST"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/TRYPTASE_TEST"
# Out:
# TRYPTASE_TEST_bioactivity_data.csv
# TRYPTASE_TEST_bioactivity_preprocessed_data.csv

# %% [markdown]
# ---
